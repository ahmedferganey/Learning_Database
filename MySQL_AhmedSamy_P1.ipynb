# %% [markdown]
# # Use Docker
# docker run -d -v /var/run/docker.sock:/tmp/docker.sock -v /etc/hosts:/tmp/hosts asami76/docker-hoster
#
#
# ![image.png](attachment:image.png)
#
# docker-compose -f mysql.yml up -d
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# # errors
#
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
# ![image-3.png](attachment:image-3.png)
# ![image-4.png](attachment:image-4.png)
# ![image-5.png](attachment:image-5.png)
# ![image-6.png](attachment:image-6.png)

# %% [markdown]
# i run these two commands :
#
# docker run -d -v /var/run/docker.sock:/tmp/docker.sock -v /etc/hosts:/tmp/hosts asami76/docker-hoster
# docker-compose -f mysql.yml up -d
#
# and mysql.yml is
# "version: '3.7'
#
# services:
#
#   mysql-db:
#     image: mysql:latest
#     container_name: mysql-db
#     hostname: mysql-db
#     restart: always
#     volumes:
#       - ./databases:/usr/databases
#     ports:
#       - 3306:3306 # Changed host port to 3307
#       - 33060:33060
#     environment:
#       MYSQL_ROOT_PASSWORD: "P@ssw0rd"
#
#   mysql-workbench:
#     image: linuxserver/mysql-workbench:latest
#     container_name: mysql-workbench
#     hostname: mysql-workbench
#     environment:
#       - PUID=1000
#       - PGID=1000
#     volumes:
#       - ./databases:/usr/databases
#     ports:
#       - 3000:3000
#     cap_add:
#       - IPC_LOCK
#     restart: unless-stopped
#
#   jupyter:
#     image: asami76/allspark:latest
#     container_name: jupyter
#     hostname: jupyter
#     environment:
#       - PUID=1000
#       - PGID=1000
#     volumes:
#       - ./databases:/home/jovyan/
#     ports:
#       - 8888:8888
#     restart: unless-stopped"
#
#
# then i go to website "http://mysql-workbench:3000/"
#
# and added a connection and it is added but it gives me this warning
# "
#
# incompatible/nonstandard server version connection protocol detected (9.0.0)
#
# a connection to this database can be established but sime MySQL workbench feature may not work properly since the database is not fully compatible with the supported version mysql
# my sql workbench is developed and tested for mysql server version 5.6, 5.7,8
# please note there may be some incopatibilites with version 8.4
# "
#
# the solution in this readjustment of yml file :
#
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# # MYSQL Client on VS code
#
# https://marketplace.visualstudio.com/items?itemName=cweijan.vscode-database-client2
